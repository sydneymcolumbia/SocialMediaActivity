# %% [markdown]
# Has instagram reels kept me from migrating to TikTok? YUP

# %%
from pandas import read_csv
import pandas as pd

# provide read_csv() a URL pointing to the CSV
socialmedia = pd.read_csv("https://raw.githubusercontent.com/sydneymcolumbia/SocialMediaActivity/main/DataCollectionSocialMedia%20%20-%20Sheet1.csv")

# look at the first few lines of the table
socialmedia.head(20)
# Out:
#         Date  Instagram  Facebook  TikTok
# 0    March 1         55     32.00    0.00
# 1    March 2         44      0.00    0.00
# 2    March 3         39      1.00    0.00
# 3    March 4         10      8.00   45.00
# 4    March 5         13     13.00    0.00
# 5    March 6         39      0.00    0.00
# 6    March 7         22      9.00    0.00
# 7    March 8         37      0.00    0.00
# 8    March 9         41      0.00   57.00
# 9   March 10         72      7.00    0.00
# 10  March 11         28      4.00    0.00
# 11  March 12         72      4.00   89.00
# 12  March 13         72      0.13    0.00
# 13  March 14         28      0.23   22.00
# 14  March 15         24      2.00    0.26
# 15  March 16         40      0.00    0.00
# 16  March 17        188      0.00    0.00
# 17  March 18         15      7.00    0.00
# 18  March 19         30      2.00    0.00
# 19  March 20         60      8.00   48.00

# %%
#checking the size of the file
socialmedia.shape
# Out:
# (20, 4)

# %%
socialmedia = pd.read_csv("https://raw.githubusercontent.com/sydneymcolumbia/SocialMediaActivity/main/DataCollectionSocialMedia%20%20-%20Sheet1.csv")

from matplotlib.ticker import ScalarFormatter
# import the function that makes line plots from plotly.express
from plotly.express import bar
import matplotlib.pyplot as plt
import pandas as pd
#import matplotlib.pyplot as plt
#from plotly.express import histogram

#histogram(socialmedia,x="Date", nbins=100)

df = pd.DataFrame(socialmedia)

#draw the graph, with "Date" on the y-axis
#bar(socialmedia,y="Date")

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
# Plot the data using bar method

plt.xticks(rotation='vertical')
plt.bar(X, Y, color='b')
plt.title("Minutes I wasted on Instagram this month")
#look at ScalarFormatter - angles labels, to space out the marches
plt.xlabel("Day")
plt.ylabel("Platform")
# Out:
# Text(0, 0.5, 'Platform')
